# %%
def createDummies(df, var_name): # Nombre del dataframe y variable 
    dummy = pd.get_dummies(df[var_name], prefix=var_name)
    df = df.drop(var_name, axis = 1) # Borra la variable original
    df = pd.concat([df, dummy ], axis = 1)
    return df
#createDummies(data,"nombre de variable")

# %%
def sumaNulls(df,var_name):
    num1 = pd.isnull(df[var_name]).values.ravel().sum()
    num2 = pd.notnull(data[var_name]).values.ravel().sum()
    return print ("La Variable" + var_name + "tiene" + num + "valore nulos y" + num2 + "valores ")

# %%
data.dropna(axis=0, how="all")
data.dropna(axis=0, how="any")
data5["body"] = data5["body"].fillna(0)

# %%
import pandas as pd

# %%
import os
mainpath = "/Users/FRANCISCO JAVIER/Documents/GitHub/python-ml-course/datasets"
filename = "titanic/titanic3.csv"
fullpath = os.path.join(mainpath, filename)
data = pd.read_csv(fullpath)

# %%
createDummies(data,"sex")
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...
